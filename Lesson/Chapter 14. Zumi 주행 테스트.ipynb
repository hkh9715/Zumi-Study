# %% [markdown]
# <img src="image/Title.png" width=1000>

# %% [markdown]
# # Zumi 주행 테스트
#
# 여러분은 그 동안 Zumi로 다양한 명령어를 배웠습니다. 이번 챕터에서는 Zumi 주행 테스트를 해보겠습니다. 5개 구간의 코드를 작성한 다음 python의 함수로 간단하게 만들어 주행 코스를 완주해 보세요!
#
# <img src="image/ch14/road_map.png" width = 700>
#
# 주행테스트 맵 경로 : [주행테스트1](image/ch14/road_map1.jpg)
# [주행테스트2](image/ch14/road_map2.jpg)
# [주행테스트3](image/ch14/road_map3.jpg)
# [주행테스트4](image/ch14/road_map4.jpg)<br>
# <b>(이미지를 다른 이름으로 저장합니다. 용지 사이즈는 A3이고 비율 자동맞춤 관련 설정을 모두 해제하고 출력하세요. 4개의 맵을 이어 붙입니다.)</b>
#
#
# --------
#
# 스탠드 카드 경로 : [스탠드 카드](image/ch14/stand_card.jpg)<br>
# 미션 카드 경로 : [미션 카드](image/ch14/mission_card.jpg)
#
# <img src="image/ch14/stand_card.jpg" width = 400>
# <img src="image/ch14/mission_card.jpg" width = 400>
#
# <b>(이미지를 다른 이름으로 저장합니다. 용지 사이즈는 A4이고 비율 자동맞춤 관련 설정을 모두 해제하고 출력하세요.)

# %% [markdown]
# ## Step 1: 라이브러리 가져오기
# Zumi의 주행 기능을 가져오기 위해 라이브러리를 가져 옵니다. <b>만약 이 셀을 실행하지 않으면, 이후의 프로그램은 작동하지 않습니다.

# %%
from zumi.zumi import Zumi
from zumi.util.screen import Screen
import time

zumi = Zumi()
screen = Screen()

# %% [markdown]
# ## Step 2: 첫 번째 테스트 구간 - 라이트 제어하기
#
# 키보드 입력을 받아 Zumi의 라이트를 제어해 보는 구간입니다. 수행할 동작이 적혀져 있는 미션 카드를 보고 Zumi의 라이트를 알맞게 제어해 봅시다. 미션을 무사히 완료했다면 'pass'를 입력하세요.
#
# -------------------------------------------------
# #### 라이트 제어 방법
#
# `w` : 전면 라이트 3초간 켜기<br>
# `s` : 후면 라이트 3초간 켜기<br>
# `a` : 왼쪽 라이트 깜빡이 3초간 켜기<br>
# `d` : 오른쪽 라이트 깜빡이 3초간 켜기<br>
# `q` : 비상등 3초간 켜기<br>
# `e` : 모든 라이트 3초간 켜기
#
# ----------------------------------------
#
# <img src='image/ch14/mission.png' width = 400>

# %%
try:
    while True:
        
        answer = input('answer : ')
       
        if answer == 'w':
            #여기에 코딩해 보세요.
       
        elif answer == 's':
            #여기에 코딩해 보세요.

        elif answer == 'a':
            #여기에 코딩해 보세요.       

        elif answer == 'd':
            #여기에 코딩해 보세요.     

        elif answer == 'q':
            #여기에 코딩해 보세요.       

        elif answer == 'e':
            #여기에 코딩해 보세요.            

        elif answer == 'pass':
            screen.draw_text_center('SUCCESS', font_size = 30)
            time.sleep(3)
            screen.happy()
            break
            
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">answer = input('answer : ')<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">if answer == 'w':<br></span>
# <span style="margin-left: 120px;">zumi.headlights_on()<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">zumi.headlights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">elif answer == 's':<br></span>
# <span style="margin-left: 120px;">zumi.brake_lights_on()<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">zumi.brake_lights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">elif answer == 'a':<br></span>
# <span style="margin-left: 120px;">zumi.signal_left_on()<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">zumi.signal_left_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">elif answer == 'd':<br></span>
# <span style="margin-left: 120px;">zumi.signal_right_on()<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">zumi.signal_right_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">elif answer == 'q':<br></span>
# <span style="margin-left: 120px;">zumi.hazard_lights_on()<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">zumi.hazard_lights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">elif answer == 'e':<br></span>
# <span style="margin-left: 120px;">zumi.all_lights_on()<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">zumi.all_lights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">elif answer == 'pass':<br></span>
# <span style="margin-left: 120px;">screen.draw_text_center('SUCEESS', font_size = 30)<br></span>
# <span style="margin-left: 120px;">time.sleep(3)<br></span>
# <span style="margin-left: 120px;">screen.happy()<br></span>
# <span style="margin-left: 120px;">break<br></span>
#
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ## Step 3: 두 번째 테스트 구간 - 코스 주행하기
# 기본 주행과 중급 주행을 사용하여 코스를 완주해 보세요.
#
# #### 주행 경로
# <img src ="image/ch14/road4.png">

# %% [markdown]
# <br>
#
# #### 첫번째 코스 - 기본 주행하기
# `zumi.forward()`와 `zumi.turn_right()`, `zumi.turn_left()` 명령어를 사용하여 주행하세요.
# <img src="image/ch14/road1.png" width = 600>

# %%
try:
    #여기에 코딩해 보세요.
    
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.turn_left()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration=1)<br></span>
# <span style="margin-left: 80px;">zumi.turn_right()      <br></span>
#
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# <br>
#
# #### 두번째 코스 - 정지선 감지와 U턴하기
# `zumi.go_straight()`와 `zumi.left_u_turn` 명령어를 사용하여 흰색 정지선을 감지하면 멈추고 왼쪽으로 이동한 다음 U턴을 하세요.
# <img src="image/ch14/road2.png" width = 500>

# %%
try:
    #여기에 코딩해 보세요.
    
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 80px;">heading = 180<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir_readings = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right = ir_readings[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir_readings[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right < 60 and bottom_left < 60:<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(10,heading-180)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
# <span style="margin-left: 80px;">zumi.turn(heading-90)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.left_u_turn(step=6)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 0.6)<br></span>
#
# <span style="margin-left: 80px;">zumi.turn(heading)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 0.6)<br></span>
# <span style="margin-left: 80px;">zumi.turn(heading-90)<br></span>
#
# <span style="margin-left: 80px;">zumi.stop()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# <br>
#
# #### 세번째 코스 - J턴과 정지선 감지
# `zumi.j_turn()`과 `zumi.go_staright()` 명령어를 사용하여 J턴 후에 아래 방향으로 정지선을 감지할 때까지 주행하세요.
# <img src="image/ch14/road3.png" width = 600>

# %%
try:
    #여기에 코딩해 보세요.
    
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 80px;">heading = 90<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.j_turn(speed=20, step=4)<br></span>
# <span style="margin-left: 80px;">time.sleep(0.5)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir_readings = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right = ir_readings[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir_readings[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right < 60 and bottom_left < 60:<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(20,heading-180)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# <br>
#
# <img src="image/icon.png" align='left'> <b> 첫 번째, 두 번째, 세 번째 코스를 주행하는 명령어들을 모두 합친 후 실행시켜 보세요.(Zumi가 도착지점까지 주행하지 못한다면 주행 명령어들의 매개 변수를 수정하거나 주행 명령어를 추가하여 도착지점까지 올 수 있도록 코딩해 보세요.)

# %%
try:
    #여기에 코딩해 보세요.
    
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 80px;">heading = 0<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.turn_left()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration=1)<br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir_readings = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right = ir_readings[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir_readings[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right < 60 and bottom_left < 60:<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(10,heading-180)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.turn(-90)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.left_u_turn(step=6)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 0.6)<br></span>
# <span style="margin-left: 80px;">zumi.turn(0)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 0.6)<br></span>
# <span style="margin-left: 80px;">zumi.turn(-90)<br></span>
# <span style="margin-left: 80px;">zumi.j_turn(speed=20, step=4)<br></span>
# <span style="margin-left: 80px;">time.sleep(0.5)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir_readings = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right = ir_readings[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir_readings[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right < 60 and bottom_left < 60:<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(20,heading-180)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ## Step 4: 세 번째 테스트 구간 - 장애물 회피하기
# 전면 적외선 센서를 이용하여 물체가 감지되면 방향을 바꾸어 주행하고 하단 적외선센서에 검은색이 감지되면 주행을 멈춥니다.(가드레일을 표시된 자리에 배치해 주세요.)
#
# <img src ="image/ch14/road5.png" width = 700>

# %%
try:
    #여기에 코딩해 보세요.
            
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 80px;">heading = 0<br></span>
# <span style="margin-left: 80px;">zumi.forward(0.5)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">front_right = ir[0]<br></span>
# <span style="margin-left: 120px;">front_left = ir[5]<br></span>
# <span style="margin-left: 120px;">bottom_right = ir[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if front_left < 150:<br></span>
# <span style="margin-left: 160px;">print("something on left")<br></span>
# <span style="margin-left: 160px;">heading -= 15<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif front_right < 150:<br></span>
# <span style="margin-left: 160px;">print("something on right")<br></span>
# <span style="margin-left: 160px;">heading += 15<br></span>
#
# <span style="margin-left: 40px;">#             elif front_left < 130 and front_right < 130:<br></span>
# <span style="margin-left: 40px;"># #                 print("something ahead")<br></span>
# <span style="margin-left: 40px;">#                 zumi.stop(0)<br></span>
# <span style="margin-left: 40px;">#                 zumi.reverse()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right > 100 and bottom_left > 100:<br></span>
# <span style="margin-left: 160px;">zumi.stop()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(10,heading)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ## Step 5: 네 번째 테스트 구간 - 라인트레이싱
# Zumi가 검은색라인을 따라 라인트레이싱하다가 전면에 물체가 감지되면 멈춥니다.(정지 표지판을 표시된 자리에 배치해 주세요.)
#
# <img src ="image/ch14/road6.png" width = 700>

# %%
try:
    #여기에 코딩해 보세요.
            
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">try:<br></span>
# <span style="margin-left: 80px;">threshold = 100<br></span>
# <span style="margin-left: 80px;">turnSpeed = 5<br></span>
# <span style="margin-left: 80px;">forwardSpeed = 1<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right_ir = ir[1]<br></span>
# <span style="margin-left: 120px;">bottom_left_ir = ir[3]<br></span>
# <span style="margin-left: 120px;">front_right = ir[0]<br></span>
# <span style="margin-left: 120px;">front_left = ir[5]<br></span>
#
# <span style="margin-left: 120px;">if bottom_left_ir > threshold and bottom_right_ir > threshold :      <br></span>
# <span style="margin-left: 160px;">zumi.control_motors(forwardSpeed,forwardSpeed,0)<br></span>
#
# <span style="margin-left: 120px;">elif front_right < 100 and front_left < 100:<br></span>
# <span style="margin-left: 160px;">zumi.stop(0)<br></span>
# <span style="margin-left: 160px;">break<br></span>
#
# <span style="margin-left: 120px;">elif bottom_left_ir > threshold :<br></span>
# <span style="margin-left: 160px;">zumi.control_motors(turnSpeed,0,0)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif bottom_right_ir > threshold :<br></span>
# <span style="margin-left: 160px;">zumi.control_motors(0,turnSpeed,0)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ## Step 6: 다섯 번째 테스트 구간 - 주차하기
# Zumi가 후진 주차를 시작합니다. 시계방향으로 90도 회전을 하고 후진으로 이동하면서 부저 소리를 냅니다. 벽에 가까워질수록 부저 소리가 길어지고 벽이 감지되면 멈춥니다. 주차 표지판을 표시된 자리에 배치하고 아래의 셀을 실행시켜 후진 주차를 해보세요.
#
# <img src='image/ch14/road7.png' width = 300>

# %%
def check_back_ir():
    
    detectionSensor = 0
    
    back_left = zumi.read_IR('back_left')
    back_right = zumi.read_IR('back_right')
    # 후방 두개의 센서중에 감지 값이 높은 값을 사용
    if(int(back_left) <= int(back_right)):
        detectionSensor = int(back_left) 
        note_duration =detectionSensor/2
        if note_duration<10 : note_duration = 10     
            
        zumi.play_note(50,note_duration) 
    else:
        detectionSensor = int(back_right)            
        note_duration =detectionSensor/2
        if note_duration<10 : note_duration = 10
            
        zumi.play_note(50,note_duration)
    # 후방 왼쪽, 오른쪽 중에서 감지 값이 높은 값을 리턴
    return detectionSensor

def parking():
    zumi = Zumi()
    zumi. turn(-90)
    
    backIRthreshold = 20

    while True:
        backIRsensor = check_back_ir()

        if(backIRsensor < backIRthreshold):
            zumi.stop()
            print("sensor detection")
            zumi.play_note(50, 2000)
            break

        zumi.control_motors(-1,-1,0)
        
try:
    parking()

except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# `check_back_ir()`은 `parking()` 명령어를 동작시키기 위해 필요한 함수입니다. 두 함수 중 하나라도 없으면 Zumi가 후진 주차를 하지 않습니다.

# %% [markdown]
# #### Zumi가 일자로 후진하지 않는다면 `zumi.control_motors()`의 매개 변수를 조정하세요.

# %% [markdown]
# ## Step 7: 함수로 만들어 모든 코스 주행하기
# 이제 각 테스트 구간마다 Zumi가 동작하는 코드를 함수로 만들어 사용해 보겠습니다.
#
# ---
#
# * 첫 번째 테스트구간 : exam()
# * 두 번째 테스트구간 : driving()
# * 세 번째 테스트구간 : avoidance()
# * 네 번째 테스트구간 : linetracing()
# * 다섯 번째 테스트 구간 : check_back_ir(), parking()
#
# ---

# %%
def exam():
    pass # pass를 지우고 코딩해 보세요.

def driving():
    pass # pass를 지우고 코딩해 보세요.

def avoidance():
    pass # pass를 지우고 코딩해 보세요.

def linetracing():
    pass # pass를 지우고 코딩해 보세요.

def check_back_ir():
    pass # pass를 지우고 코딩해 보세요.

def parking():
    pass # pass를 지우고 코딩해 보세요.

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">def exam():<br></span>
# <span style="margin-left: 80px;">while True:<br></span>
#
# <span style="margin-left: 120px;">answer = input('answer : ')<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if answer == 'w':<br></span>
# <span style="margin-left: 160px;">zumi.headlights_on()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">zumi.headlights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif answer == 's':<br></span>
# <span style="margin-left: 160px;">zumi.brake_lights_on()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">zumi.brake_lights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif answer == 'a':<br></span>
# <span style="margin-left: 160px;">zumi.signal_left_on()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">zumi.signal_left_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif answer == 'd':<br></span>
# <span style="margin-left: 160px;">zumi.signal_right_on()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">zumi.signal_right_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif answer == 'q':<br></span>
# <span style="margin-left: 160px;">zumi.hazard_lights_on()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">zumi.hazard_lights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif answer == 'e':<br></span>
# <span style="margin-left: 160px;">zumi.all_lights_on()<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">zumi.all_lights_off()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif answer == 'pass':<br></span>
#
# <span style="margin-left: 160px;">screen.draw_text_center('SUCEESS', font_size = 30)<br></span>
# <span style="margin-left: 160px;">time.sleep(3)<br></span>
# <span style="margin-left: 160px;">screen.happy()<br></span>
# <span style="margin-left: 160px;">break        <br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">def drive():<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 80px;">heading = 0<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.turn_left()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration=1)<br></span>
# <span style="margin-left: 80px;">zumi.turn_right()<br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir_readings = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right = ir_readings[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir_readings[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right < 60 and bottom_left < 60:<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(10,heading-180)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.turn(-90)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 1.2)<br></span>
# <span style="margin-left: 80px;">zumi.left_u_turn(step=6)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 0.6)<br></span>
# <span style="margin-left: 80px;">zumi.turn(0)<br></span>
# <span style="margin-left: 80px;">zumi.forward(duration = 0.6)<br></span>
# <span style="margin-left: 80px;">zumi.turn(-90)<br></span>
# <span style="margin-left: 80px;">zumi.j_turn(speed=20, step=4)<br></span>
# <span style="margin-left: 80px;">time.sleep(0.5)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir_readings = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right = ir_readings[1]<br></span>
# <span style="margin-left: 120px;">bottom_left = ir_readings[3]<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if bottom_right < 60 and bottom_left < 60:<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.go_straight(20,heading-180)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">def avoidence():<br></span>
# <span style="margin-left: 80px;">try:<br></span>
# <span style="margin-left: 120px;">zumi = Zumi()<br></span>
# <span style="margin-left: 120px;">heading = 0<br></span>
# <span style="margin-left: 120px;">zumi.forward(0.5)<br></span>
#
# <span style="margin-left: 120px;">while True:<br></span>
# <span style="margin-left: 160px;">ir = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 160px;">front_right = ir[0]<br></span>
# <span style="margin-left: 160px;">front_left = ir[5]<br></span>
# <span style="margin-left: 160px;">bottom_right = ir[1]<br></span>
# <span style="margin-left: 160px;">bottom_left = ir[3]<br></span>
#
#
# <span style="margin-left: 160px;">if front_left < 150:<br></span>
# <span style="margin-left: 40px;">#                 print("something on left")<br></span>
# <span style="margin-left: 200px;">heading -= 15<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 160px;">elif front_right < 150:<br></span>
# <span style="margin-left: 40px;">#                 print("something on right")<br></span>
# <span style="margin-left: 200px;">heading += 15<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;">#             elif front_left < 130 and front_right < 130:<br></span>
# <span style="margin-left: 40px;"># #                 print("something ahead")<br></span>
# <span style="margin-left: 40px;">#                 zumi.stop(0)<br></span>
# <span style="margin-left: 40px;">#                 zumi.reverse()<br></span>
#
# <span style="margin-left: 160px;">if bottom_right > 100 and bottom_left > 100:<br></span>
# <span style="margin-left: 200px;">zumi.stop()<br></span>
# <span style="margin-left: 200px;">time.sleep(3)<br></span>
# <span style="margin-left: 200px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 160px;">zumi.go_straight(10,heading)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">except KeyboardInterrupt:<br></span>
# <span style="margin-left: 120px;">zumi.stop()<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">def LineTracer():<br></span>
# <span style="margin-left: 80px;">threshold = 100<br></span>
# <span style="margin-left: 80px;">turnSpeed = 5<br></span>
# <span style="margin-left: 80px;">forwardSpeed = 1<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">ir = zumi.get_all_IR_data()<br></span>
# <span style="margin-left: 120px;">bottom_right_ir = ir[1]<br></span>
# <span style="margin-left: 120px;">bottom_left_ir = ir[3]<br></span>
# <span style="margin-left: 120px;">front_right = ir[0]<br></span>
# <span style="margin-left: 120px;">front_left = ir[5]<br></span>
#
# <span style="margin-left: 120px;">if bottom_left_ir > threshold and bottom_right_ir > threshold :      <br></span>
# <span style="margin-left: 160px;">zumi.control_motors(forwardSpeed,forwardSpeed,0)<br></span>
#
# <span style="margin-left: 120px;">elif front_right < 100 and front_left < 100:<br></span>
# <span style="margin-left: 160px;">zumi.stop(0)<br></span>
# <span style="margin-left: 160px;">break<br></span>
#
# <span style="margin-left: 120px;">elif bottom_left_ir > threshold :<br></span>
# <span style="margin-left: 160px;">zumi.control_motors(turnSpeed,0,0)<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">elif bottom_right_ir > threshold :<br></span>
# <span style="margin-left: 160px;">zumi.control_motors(0,turnSpeed,0)<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# ### 해결 방법
#
# <br>
# <font size =3>
#     <details>
#         <summary><span style="color:blue"><u>해결 방법을 보려면 여기를 클릭하세요!</u></span></summary>
#             <font face="Courier"><br>
# <span style="margin-left: 40px;">def check_back_ir():<br></span>
#
# <span style="margin-left: 80px;">detectionSensor = 0<br></span>
#
# <span style="margin-left: 80px;">back_left = zumi.read_IR('back_left')<br></span>
# <span style="margin-left: 80px;">back_right = zumi.read_IR('back_right')<br></span>
# <span style="margin-left: 80px;"># 후방 두개의 센서중에 감지 값이 높은 값을 사용<br></span>
# <span style="margin-left: 80px;">if(int(back_left) <= int(back_right)):<br></span>
# <span style="margin-left: 120px;">detectionSensor = int(back_left) <br></span>
# <span style="margin-left: 120px;">note_duration =detectionSensor/2<br></span>
# <span style="margin-left: 120px;">if note_duration<10 : note_duration = 10     <br></span>
#
# <span style="margin-left: 120px;">zumi.play_note(50,note_duration) <br></span>
# <span style="margin-left: 80px;">else:<br></span>
# <span style="margin-left: 120px;">detectionSensor = int(back_right)            <br></span>
# <span style="margin-left: 120px;">note_duration =detectionSensor/2<br></span>
# <span style="margin-left: 120px;">if note_duration<10 : note_duration = 10<br></span>
#
# <span style="margin-left: 120px;">zumi.play_note(50,note_duration)<br></span>
# <span style="margin-left: 80px;"># 후방 왼쪽, 오른쪽 중에서 감지 값이 높은 값을 리턴<br></span>
# <span style="margin-left: 80px;">return detectionSensor<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 40px;">def parking():<br></span>
# <span style="margin-left: 80px;">zumi = Zumi()<br></span>
# <span style="margin-left: 80px;">zumi. turn(-90)<br></span>
#
# <span style="margin-left: 80px;">backIRthreshold = 20<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 80px;">while True:<br></span>
# <span style="margin-left: 120px;">backIRsensor = check_back_ir()<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">if(backIRsensor < backIRthreshold):<br></span>
# <span style="margin-left: 160px;">zumi.stop()<br></span>
# <span style="margin-left: 160px;">print("sensor detection")<br></span>
# <span style="margin-left: 160px;">zumi.play_note(50, 2000)<br></span>
# <span style="margin-left: 160px;">break<br></span>
# <span style="margin-left: 40px;"><br></span>
# <span style="margin-left: 120px;">zumi.control_motors(-1,-1,0)<br></span>
#             </font>
#     </details>
# </font>

# %% [markdown]
# 함수로 전부 제작 하였다면 Zumi를 Start Line에 배치하고 아래의 셀을 실행시켜보세요. 만약 Zumi가 끝까지 완주하지 못한다면 Zumi 명령어의 매개 변수 값을 조정해 보세요.

# %%
try:
    exam()
    driving()
    avoidence()
    linetracing()
    parking()
    
except KeyboardInterrupt:
    zumi.stop()

# %% [markdown]
# ### Zumi가 5개의 테스트 구간을 안전하게 주행 했나요? 모든 테스트 코스를 통과했다면 여러분은 Zumi 주행 테스트에 합격하였습니다!
